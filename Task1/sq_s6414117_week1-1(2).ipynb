# %% [markdown]
# Use Markdown to enter the header and credentials:
#
# Answers for Week 1
#
# * Name: Isabelle Rosa Frank
# * Username: irfrank
# * Student s-number: S6414117
# * Group (AS1, etc.): AS5

# %%
x=22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# ![image.jpg](attachment:image.jpg)

# %%
x=6
x*=5
x*=4
x*=3
x*=2
x*=1
print (x)
# Out:
# 720

# %%
from scipy.constants import h
f= 2.42e28
E= h*f
print (E)
# Out:
# 1.6035089763e-05

# %%
from scipy.constants import G
m1= 7.342e22
m2= 5.9722e24
r= 385000.6e3
F= G*m1*m2/(r**2)
print (F)
# Out:
# 1.974384051807571e+20

# %%
x1 = 10 #define x1 as 10
x2 = 22/7 #define x2 as 22/7
print(x1, end="") #prints x1 but doesn't go to the next row
print(x2, end="") #prints value of x2 but doesn't go to the next row
# Out:
# 103.142857142857143
